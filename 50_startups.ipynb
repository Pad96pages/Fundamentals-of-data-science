# %%
#Train-test split for preprocessing on '50_Startups' data
import pandas as pd
df = pd.read_csv("50_Startups.csv")
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
#selecting specific row and column to manipulate data
# Features (all columns except the last)
x = df.iloc[:,:-1]
x.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State
# 0  165349.20       136897.80        471784.10    New York
# 1  162597.70       151377.59        443898.53  California
# 2  153441.51       101145.55        407934.54     Florida
# 3  144372.41       118671.85        383199.62    New York
# 4  142107.34        91391.77        366168.42     Florida

# %%
#dropping a column profit
z = df.drop(columns = "Profit")
z.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State
# 0  165349.20       136897.80        471784.10    New York
# 1  162597.70       151377.59        443898.53  California
# 2  153441.51       101145.55        407934.54     Florida
# 3  144372.41       118671.85        383199.62    New York
# 4  142107.34        91391.77        366168.42     Florida

# %%
y = df.Profit
y.head()
# Out:
# 0    192261.83
# 1    191792.06
# 2    191050.39
# 3    182901.99
# 4    166187.94
# Name: Profit, dtype: float64

# %%
#splitting your data into training and testing sets.
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x,y,test_size = 0.25, random_state = 0)
xtrain.head()
# Out:
#     R&D Spend  Administration  Marketing Spend       State
# 34   46426.07       157693.92        210797.67  California
# 18   91749.16       114175.79        294919.57     Florida
# 7   130298.13       145530.06        323876.68     Florida
# 14  119943.24       156547.42        256512.92     Florida
# 45    1000.23       124153.04          1903.93    New York

# %%
#Creating a box plot of the "Age" column from a 
import matplotlib.pyplot as plt
import seaborn as sns
plt.boxplot(df['R&D Spend'] ,vert=True)
plt.show()

# %%
df['R&D Spend'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>
